# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from time import sleep
import requests
import re
import pandas as pd
import numpy as np
import os

# %%
url = 'https://search.shopping.naver.com/catalog/26529080523?NaPm=ct%3Dkyy8o668%7Cci%3Dd208eddde71b1ca5539768472c04ba35bdf34542%7Ctr%3Dslcc%7Csn%3D95694%7Chk%3D431f9f3ce0eb19ac9cbb2098be40258b1f5e675f'

# %%
options = webdriver.ChromeOptions()
options.add_argument('window-size=1920x1080')
options.add_argument('disable-gpu')
options.add_argument(f'user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36')

driver = webdriver.Chrome('C:/Users/Itshony/Desktop/chromedriver_win32/chromedriver.exe', options =options)

driver.get(url)
driver.implicitly_wait(3)


try: 
    driver.get_screenshot_as_file('naver_shopping.png')
except:
    'There is no alert'

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}

# Selenium
driver = webdriver.Chrome('C:/Users/Itshony/Desktop/chromedriver_win32/chromedriver.exe') # webdriver = chrome
driver.implicitly_wait(3)
driver.get(url)

# html
req = requests.get(url)
html = req.text 
soup = BeautifulSoup(html, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
shopping_review = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[2]/div/div[2]/ul/li[4]/a/strong'
satis = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/div[2]/div[2]/div/ul/li[2]/a'

# %%
# 쇼핑몰 리뷰 보기 
driver.find_element_by_xpath(shopping_review).click()
sleep(2)

# %%
# 만족도 관련 리뷰 가져오기 
driver.find_element_by_xpath(satis).click()
sleep(2)

# %% [markdown]
# ### 리뷰
# - 한 페이지당 20개

# %%
# 리뷰
review = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li['+str(i)+']'

# 별점
star = '/div[1]/span[1]'

# 제목
title = '/div[2]/div/em'

# 리뷰
review_text = '/div[2]/div/p'

# %%
driver.find_element_by_xpath(review+star).text[2:]
# Out:
# '5'

# %%
driver.find_element_by_xpath(review+title).text
# Out:
# '안녕하세요 제가 리뷰를 남기게 될줄이야.저는 원래 집에'

# %%
driver.find_element_by_xpath(review+review_text).text
# Out:
# '안녕하세요 제가 리뷰를 남기게 될줄이야.저는 원래 집에 컴이 없어서 항상 사야 된다고는 생각했지만 성능이 맘에 들면 가격이 터무니 없이 비싸고 가격을 보자니 성능이 맘에 안차고 이렇게 결정장애를 가지고 지내기를 1년이 되었습니다.근데 저는 어차피 수업용으로 사용할거라서 욕심을 버리고 다시 노트북 구매에 열을 올리던중 노트북플러스2를 알게되었습니다. 윈도우도 기본설치 되어있구 메모리도 손쉽게 교체가 가능한점이 제일 맘에 들었구요\n실제로 받아보니 화면도 너무크고 밝고\n컴퓨터 돌아가는 속도도 굉장히 빨라서 너무 만족해하고 있습니다\n제 사진에서도 보시면 알겠지만 색깔도 흰색과 많이 고민했지만 그레이가 고급짐이 뿜뿜합니대\n윈도우11도 설치가 되서 그런건지 회사 컴퓨터랑은 배경이 많이 다르더라구요\n저처럼 가격이랑 성능 둘 계신분이라면 고민하지 않으셔도 될것 같아요\n디자인이며 제일중요한 작업속도를 생각하신다면 또 이시기에 저렴하지만'

# %%
stars = []
titles = []
reviews = []

cnt = 1 # 리뷰 index 
page =1

# %%
for i in range(1, 21):
    review = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li['+str(i)+']'
    stars.append(driver.find_element_by_xpath(review+star).text[2:])
    titles.append(driver.find_element_by_xpath(review+title).text)
    reviews.append(driver.find_element_by_xpath(review+review_text).text)

# %%
page = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/div[3]/a[2]'

# %%
driver.find_element_by_xpath(page).click()
sleep(2)

# %%
item = driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[1]/h2').text

# %%
prize = driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]').text[3:-1]

# %%
df = pd.DataFrame( columns = ['star','title','review'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [star, title, review]
# Index: []

# %%
df.loc[1] = ['ㅁ','ㅁ','ㅁ','ㅁ','ㅁ']

# %%
test = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li[1]]'
test_ = '/div[1]/span[1]'

# %%
print(test+test_)
# Out:
# /html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li[1]]/div[1]/span[1]

# %%
print(driver.find_element_by_xpath(test).text)
# Out:
# 평점5

# %%
import time

# %%
# 별점
star = '/div[1]/span[1]'

# 제목
title = '/div[2]/div/em'

# 리뷰
review_text = '/div[2]/div/p'

/html/body/div[2]/div[2]/div[2]/div[3]/div[5]/div[2]/ul/li['+str(j)+']/div/div[2]'

/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li[4]/div[2]/div

/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li[4]/div[1]

# %%
driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li[4]/div[2]/div').text
# Out:
# '초등학교 입학선물로 뭘할까고민하다가코로나로 인해 초1도 개인컴이 준비물이된 시대라가성비노트북을택했습니다!삼성을 선택한 이유는 에이에스센터가 전국어디나 많고, 믿고쓸수있을것같아 삼성\n초등학교 입학선물로 뭘할까고민하다가\n코로나로 인해 초1도 개인컴이 준비물이된 시대라\n가성비노트북을택했습니다!\n삼성을 선택한 이유는 에이에스센터가 전국어디나 많고, 믿고쓸수있을것같아 삼성노트북플러스2를 구매했습니다!\n그다음, 추가구성품이 맘에들어서입니다!\n윈도우 11정품. 램4GB. 한컴오피스(아래한글). 노트북커버. 마우스. 잘받았습니다~!!\n저는 추가로 스스디 512로교체했습니다.스스디교체도 잘됐어요!\n그리고 또 좋았던점은 노트북뒷면에 셀프로 스스디와 h디디를 추가할수있게 넘잘되있었어요\n아쉬운점은, 무게가 들고다니기엔 좀 있는편같았습니다.\n그래도 가성비노트북 잘샀다고 생각합니다 굿!'

# %%
for j in range(1, 3):
    page = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/div[3]/a['+str(j)+']'
    driver.find_element_by_xpath(page).click()
    time.sleep(2)
    for i in range(1, 21):
        
        review = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[6]/ul/li['+str(i)+']'

        star_re = driver.find_element_by_xpath(review+star).text[2:]
        title_re = driver.find_element_by_xpath(review+title).text
        review_re = driver.find_element_by_xpath(review+review_text).text
        
        if j == 1:
            df.loc[i-1] = [star_re, title_re, review_re]
            #print(df)
        else:
            df = df.append({'star':star_re, "title":title_re, "review":review_re}, ignore_index=True)

# %%
df['review']
# Out:
# 0     안녕하세요 제가 리뷰를 남기게 될줄이야.저는 원래 집에 컴이 없어서 항상 사야 된다...
# 1     아무것도 모르는 컴맹이에요. 라이브보고 아저씨 믿고(설명을 너무 잘하심) 샀어요\n...
# 2     부모님 노트북이 삐삐-소리가 난다하여 교체하기로 하고 둘러보다 삼성이나 엘지로 해드...
# 3     삼성노트북 리뷰\n이사후에 누나가 가전제품을 선물로 사준다고 하기에 얼른 다나와 사...
# 4     가성비 좋은 컴퓨터입니다! 아버지께서 쓰시는 컴퓨터가 오래 되어 선물해드릴 용도로 ...
# 5     노트북 구매하려고 여기저기 알아보던중 저한테 꼭 맞는 제품일것 같아서 찜해두고 라이...
# 6     몇 년간 쓰던 노트북이 충전조차 안되서 수리해야하던참에 착한 가격을 보고 구매했어요...
# 7     저는 노후된 노트북이 가정용 쓰다가 업무용으로 부족하여 스마트폰으로 거의 다되지만 ...
# 8     저는 화이트로 구매를 하였는데요 순백의 화이트 색상이라 깔끔하고 귀티가 납니다. 노...
# 9     집에 컴퓨터가 없으니 불편한점이 많더라구용.. 첨엔 원래 가지고있던 컴퓨터를 처분하...
# 10    문서작업 및 동영상 감상 목적으로 노트북을 찾고 있었습니다. 덧붙여 브랜드도 있고 ...
# 11    막상 노트북 사려면 고민을 많이함\n하지만 나는 유튜브 50만원 노트북 추천 영상을...
# 12    아이들 온라인 수업겸 학교 과제용으로 다시 구입했습니다. 더 비싼 가격의 고사양 노...
# 13    노트북을 사려던 찰나 라방 혜택이 좋다고 해서 4일을\n기다리고 라방중에 구매했습니...
# 14    라이브를 통해서 저렴하게 구입했는데 정말 너무 좋아요\n그냥 쇼호스트님 말대로 열어...
# 15    기존 노트북을 사용하고 있는데\n회사 운영프로그램이 업그레이드 되면서\n기존의 윈도...
# 16    재택근무가 활성화되면서 그에 알맞는 사양의 노트북이 필요해서 검색하던 중 이 제품을...
# ...

# %%
df.to_csv("Naver_Shopping_review.csv", index = False, encoding='utf-8')
